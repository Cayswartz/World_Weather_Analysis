# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

from citipy import citipy 

from config import weather_api_key
import json

# %%
# List for holding lat_lngs and cities
coordinates = []

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats, lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

        
        # Run an API request for each of the cities.
    try:
            # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
            # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
            # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Description": city_desc,
                              "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
        print("-----------------------------")
        print("Data Retrieval Complete      ")
        print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | nizhneyansk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 1 | natal
# Processing Record 4 of Set 1 | bambous virieux
# Processing Record 5 of Set 1 | quelimane
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | marsta
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | souillac
# Processing Record 12 of Set 1 | naze
# Processing Record 13 of Set 1 | port macquarie
# Processing Record 14 of Set 1 | rawannawi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 1 | gravdal
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | nemuro
# Processing Record 18 of Set 1 | tawkar
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 1 | saint stephen
# Processing Record 20 of Set 1 | kruisfontein
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | galle
# Processing Record 23 of Set 1 | ranfurly
# Processing Record 24 of Set 1 | kodinar
# Processing Record 25 of Set 1 | zenzeli
# Processing Record 26 of Set 1 | barabai
# Processing Record 27 of Set 1 | holme
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | kampong thum
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | arraial do cabo
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | attawapiskat
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | pandelys
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 1 | severo-kurilsk
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 1 | tsienyane
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 1 | mahebourg
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | mangan
# Processing Record 45 of Set 1 | tessalit
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | chagda
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | sisian
# Processing Record 3 of Set 2 | mehamn
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | boguchany
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | mezen
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | sabang
# Processing Record 10 of Set 2 | orel-izumrud
# Processing Record 11 of Set 2 | makakilo city
# Processing Record 12 of Set 2 | samandag
# Processing Record 13 of Set 2 | sao filipe
# Processing Record 14 of Set 2 | sitka
# Processing Record 15 of Set 2 | east london
# Processing Record 16 of Set 2 | tasiilaq
# Processing Record 17 of Set 2 | taolanaro
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | taltal
# Processing Record 20 of Set 2 | khandyga
# Processing Record 21 of Set 2 | santa lucia
# Processing Record 22 of Set 2 | saldanha
# Processing Record 23 of Set 2 | sataua
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 2 | shingu
# Processing Record 25 of Set 2 | pangnirtung
# Processing Record 26 of Set 2 | hammerfest
# Processing Record 27 of Set 2 | silute
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | tuktoyaktuk
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | butaritari
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | paamiut
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | mahdasht
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | aporawan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | corsicana
# Processing Record 45 of Set 2 | biak
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | lodwar
# Processing Record 48 of Set 2 | mayumba
# Processing Record 49 of Set 2 | alofi
# Processing Record 50 of Set 2 | casablanca
# Processing Record 1 of Set 3 | portland
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | nishihara
# Processing Record 5 of Set 3 | cape town
# Processing Record 6 of Set 3 | pa sang
# Processing Record 7 of Set 3 | vila franca do campo
# Processing Record 8 of Set 3 | tuggurt
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 3 | constitucion
# Processing Record 10 of Set 3 | dingle
# Processing Record 11 of Set 3 | hervey bay
# Processing Record 12 of Set 3 | acajutla
# Processing Record 13 of Set 3 | marathon
# Processing Record 14 of Set 3 | biltine
# Processing Record 15 of Set 3 | ambodifototra
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 3 | isangel
# Processing Record 17 of Set 3 | phoenixville
# Processing Record 18 of Set 3 | awjilah
# Processing Record 19 of Set 3 | thompson
# Processing Record 20 of Set 3 | sentyabrskiy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 3 | goderich
# Processing Record 22 of Set 3 | talcahuano
# Processing Record 23 of Set 3 | falun
# Processing Record 24 of Set 3 | ponta do sol
# Processing Record 25 of Set 3 | provideniya
# Processing Record 26 of Set 3 | srednekolymsk
# Processing Record 27 of Set 3 | esperance
# Processing Record 28 of Set 3 | mombaca
# Processing Record 29 of Set 3 | henties bay
# Processing Record 30 of Set 3 | college
# Processing Record 31 of Set 3 | vila
# Processing Record 32 of Set 3 | loukhi
# Processing Record 33 of Set 3 | tendukheda
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | mtambile
# Processing Record 36 of Set 3 | malanje
# Processing Record 37 of Set 3 | numan
# Processing Record 38 of Set 3 | tecoanapa
# Processing Record 39 of Set 3 | bud
# Processing Record 40 of Set 3 | ovre ardal
# Processing Record 41 of Set 3 | torbay
# Processing Record 42 of Set 3 | tura
# Processing Record 43 of Set 3 | lagoa
# Processing Record 44 of Set 3 | amderma
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 3 | kapaa
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | sorland
# Processing Record 48 of Set 3 | vilyuysk
# Processing Record 49 of Set 3 | tiksi
# Processing Record 50 of Set 3 | flinders
# Processing Record 1 of Set 4 | hilo
# Processing Record 2 of Set 4 | bengkulu
# Processing Record 3 of Set 4 | virginia beach
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | leningradskiy
# Processing Record 6 of Set 4 | ixtapa
# Processing Record 7 of Set 4 | alugan
# Processing Record 8 of Set 4 | chuy
# Processing Record 9 of Set 4 | atherton
# Processing Record 10 of Set 4 | narsaq
# Processing Record 11 of Set 4 | praia da vitoria
# Processing Record 12 of Set 4 | marsh harbour
# Processing Record 13 of Set 4 | salym
# Processing Record 14 of Set 4 | hithadhoo
# Processing Record 15 of Set 4 | murgab
# Processing Record 16 of Set 4 | kentau
# Processing Record 17 of Set 4 | bodden town
# Processing Record 18 of Set 4 | mercedes
# Processing Record 19 of Set 4 | oranjemund
# Processing Record 20 of Set 4 | lovozero
# Processing Record 21 of Set 4 | xining
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | shelburne
# Processing Record 24 of Set 4 | mahaicony
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 4 | san patricio
# Processing Record 26 of Set 4 | inhambane
# Processing Record 27 of Set 4 | west plains
# Processing Record 28 of Set 4 | sao joao da barra
# Processing Record 29 of Set 4 | gumdag
# Processing Record 30 of Set 4 | finote selam
# Processing Record 31 of Set 4 | salalah
# Processing Record 32 of Set 4 | guerrero negro
# Processing Record 33 of Set 4 | jacareacanga
# Processing Record 34 of Set 4 | burica
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 4 | san carlos del zulia
# Processing Record 36 of Set 4 | bethel
# Processing Record 37 of Set 4 | walvis bay
# Processing Record 38 of Set 4 | nizwa
# Processing Record 39 of Set 4 | minas
# Processing Record 40 of Set 4 | shakawe
# Processing Record 41 of Set 4 | bella union
# Processing Record 42 of Set 4 | arman
# Processing Record 43 of Set 4 | deogarh
# Processing Record 44 of Set 4 | ulaangom
# Processing Record 45 of Set 4 | finnsnes
# Processing Record 46 of Set 4 | nampula
# Processing Record 47 of Set 4 | kieta
# Processing Record 48 of Set 4 | lata
# Processing Record 49 of Set 4 | road town
# Processing Record 50 of Set 4 | hamilton
# Processing Record 1 of Set 5 | touros
# Processing Record 2 of Set 5 | gat
# Processing Record 3 of Set 5 | port hedland
# Processing Record 4 of Set 5 | ingham
# Processing Record 5 of Set 5 | loudi
# Processing Record 6 of Set 5 | beidao
# Processing Record 7 of Set 5 | mogadishu
# Processing Record 8 of Set 5 | santarem
# Processing Record 9 of Set 5 | tsihombe
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 5 | bjornevatn
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | luganville
# Processing Record 13 of Set 5 | talnakh
# Processing Record 14 of Set 5 | ostersund
# Processing Record 15 of Set 5 | mount gambier
# Processing Record 16 of Set 5 | fenoarivo
# Processing Record 17 of Set 5 | basco
# Processing Record 18 of Set 5 | barrow
# Processing Record 19 of Set 5 | mariental
# Processing Record 20 of Set 5 | riberalta
# Processing Record 21 of Set 5 | kerman
# Processing Record 22 of Set 5 | wesselsbron
# Processing Record 23 of Set 5 | dunmore town
# Processing Record 24 of Set 5 | boa vista
# Processing Record 25 of Set 5 | suntar
# Processing Record 26 of Set 5 | port blair
# Processing Record 27 of Set 5 | faanui
# Processing Record 28 of Set 5 | asau
# Processing Record 29 of Set 5 | nichinan
# Processing Record 30 of Set 5 | kahului
# Processing Record 31 of Set 5 | hasaki
# Processing Record 32 of Set 5 | sao paulo de olivenca
# Processing Record 33 of Set 5 | san quintin
# Processing Record 34 of Set 5 | tarata
# Processing Record 35 of Set 5 | vardo
# Processing Record 36 of Set 5 | naliya
# Processing Record 37 of Set 5 | bargal
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 5 | chapais
# Processing Record 39 of Set 5 | kortkeros
# Processing Record 40 of Set 5 | bolungarvik
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 5 | byron bay
# Processing Record 42 of Set 5 | hay river
# Processing Record 43 of Set 5 | barentsburg
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 5 | carutapera
# Processing Record 45 of Set 5 | alice springs
# Processing Record 46 of Set 5 | port lincoln
# Processing Record 47 of Set 5 | pacific grove
# Processing Record 48 of Set 5 | fare
# Processing Record 49 of Set 5 | klaksvik
# Processing Record 50 of Set 5 | itaquyry
# Processing Record 1 of Set 6 | muromtsevo
# Processing Record 2 of Set 6 | padang
# Processing Record 3 of Set 6 | norman wells
# Processing Record 4 of Set 6 | liberty
# Processing Record 5 of Set 6 | namibe
# Processing Record 6 of Set 6 | udachnyy
# Processing Record 7 of Set 6 | sinnamary
# Processing Record 8 of Set 6 | bukachacha
# Processing Record 9 of Set 6 | babanusah
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 6 | tanshui
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 6 | astana
# Processing Record 12 of Set 6 | tanout
# Processing Record 13 of Set 6 | malwan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 6 | najran
# Processing Record 15 of Set 6 | san jeronimo de tunan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 6 | port hawkesbury
# Processing Record 17 of Set 6 | houlung
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 6 | hirara
# Processing Record 19 of Set 6 | belaya gora
# Processing Record 20 of Set 6 | saint-philippe
# Processing Record 21 of Set 6 | myaundzha
# Processing Record 22 of Set 6 | vanavara
# Processing Record 23 of Set 6 | kavaratti
# Processing Record 24 of Set 6 | muzhi
# Processing Record 25 of Set 6 | rabo de peixe
# Processing Record 26 of Set 6 | iralaya
# Processing Record 27 of Set 6 | bowen
# Processing Record 28 of Set 6 | cazaje
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 6 | meulaboh
# Processing Record 30 of Set 6 | bria
# Processing Record 31 of Set 6 | mayo
# Processing Record 32 of Set 6 | olafsvik
# Processing Record 33 of Set 6 | pulandian
# Processing Record 34 of Set 6 | iqaluit
# Processing Record 35 of Set 6 | vaitupu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 6 | sinop
# Processing Record 37 of Set 6 | hofn
# Processing Record 38 of Set 6 | oskarshamn
# Processing Record 39 of Set 6 | santa fe
# Processing Record 40 of Set 6 | lorengau
# Processing Record 41 of Set 6 | yamada
# Processing Record 42 of Set 6 | naron
# Processing Record 43 of Set 6 | pozo colorado
# Processing Record 44 of Set 6 | mar del plata
# Processing Record 45 of Set 6 | tyup
# Processing Record 46 of Set 6 | longyearbyen
# Processing Record 47 of Set 6 | cayenne
# Processing Record 48 of Set 6 | middelburg
# Processing Record 49 of Set 6 | tikapur
# Processing Record 50 of Set 6 | marzuq
# Processing Record 1 of Set 7 | hvolsvollur
# Processing Record 2 of Set 7 | bairiki
# Processing Record 3 of Set 7 | jacqueville
# Processing Record 4 of Set 7 | awbari
# Processing Record 5 of Set 7 | huarmey
# Processing Record 6 of Set 7 | lusambo
# Processing Record 7 of Set 7 | fairbanks
# Processing Record 8 of Set 7 | juneau
# Processing Record 9 of Set 7 | quatre cocos
# Processing Record 10 of Set 7 | prigorodnyy
# Processing Record 11 of Set 7 | gizo
# Processing Record 12 of Set 7 | porto walter
# Processing Record 13 of Set 7 | puerto leguizamo
# Processing Record 14 of Set 7 | baymak
# Processing Record 15 of Set 7 | cidreira
# Processing Record 16 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 7 | ulundi
# Processing Record 18 of Set 7 | mitu
# Processing Record 19 of Set 7 | corrente
# Processing Record 20 of Set 7 | camopi
# Processing Record 21 of Set 7 | joshimath
# Processing Record 22 of Set 7 | ewa beach
# Processing Record 23 of Set 7 | lumberton
# Processing Record 24 of Set 7 | champerico
# Processing Record 25 of Set 7 | dalinghe
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 7 | leh
# Processing Record 27 of Set 7 | tuensang
# Processing Record 28 of Set 7 | muros
# Processing Record 29 of Set 7 | aleksandrovka
# Processing Record 30 of Set 7 | richards bay
# Processing Record 31 of Set 7 | uarini
# Processing Record 32 of Set 7 | sakakah
# Processing Record 33 of Set 7 | havoysund
# Processing Record 34 of Set 7 | xichang
# Processing Record 35 of Set 7 | jaipur hat
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 7 | toliary
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 7 | stornoway
# Processing Record 38 of Set 7 | aksu
# Processing Record 39 of Set 7 | oranjestad
# Processing Record 40 of Set 7 | la ronge
# Processing Record 41 of Set 7 | mecca
# Processing Record 42 of Set 7 | chokurdakh
# Processing Record 43 of Set 7 | codrington
# Processing Record 44 of Set 7 | cherskiy
# Processing Record 45 of Set 7 | odweyne
# Processing Record 46 of Set 7 | pavino
# Processing Record 47 of Set 7 | dobryatino
# Processing Record 48 of Set 7 | weihai
# Processing Record 49 of Set 7 | svetlaya
# Processing Record 50 of Set 7 | beringovskiy
# Processing Record 1 of Set 8 | sao jose da tapera
# Processing Record 2 of Set 8 | skalistyy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 8 | teguise
# Processing Record 4 of Set 8 | katsuura
# Processing Record 5 of Set 8 | margate
# Processing Record 6 of Set 8 | dudinka
# Processing Record 7 of Set 8 | berbera
# Processing Record 8 of Set 8 | filadelfia
# Processing Record 9 of Set 8 | saint-augustin
# Processing Record 10 of Set 8 | dunedin
# Processing Record 11 of Set 8 | westlock
# Processing Record 12 of Set 8 | mentok
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 8 | moron
# Processing Record 14 of Set 8 | oktyabrskoye
# Processing Record 15 of Set 8 | san andres
# Processing Record 16 of Set 8 | sao felix do xingu
# Processing Record 17 of Set 8 | lompoc
# Processing Record 18 of Set 8 | tiarei
# Processing Record 19 of Set 8 | mao
# Processing Record 20 of Set 8 | irtyshskiy
# Processing Record 21 of Set 8 | boyuibe
# Processing Record 22 of Set 8 | ust-omchug
# Processing Record 23 of Set 8 | aboisso
# Processing Record 24 of Set 8 | riviere-au-renard
# Processing Record 25 of Set 8 | rio grande
# Processing Record 26 of Set 8 | kamenka
# Processing Record 27 of Set 8 | mwinilunga
# Processing Record 28 of Set 8 | hambantota
# Processing Record 29 of Set 8 | banjar
# Processing Record 30 of Set 8 | roura
# Processing Record 31 of Set 8 | brae
# Processing Record 32 of Set 8 | te anau
# Processing Record 33 of Set 8 | borkenes
# Processing Record 34 of Set 8 | mys shmidta
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 8 | bac lieu
# Processing Record 36 of Set 8 | ostroda
# Processing Record 37 of Set 8 | nanortalik
# Processing Record 38 of Set 8 | harrisburg
# Processing Record 39 of Set 8 | lagos
# Processing Record 40 of Set 8 | galesong
# Processing Record 41 of Set 8 | altar
# Processing Record 42 of Set 8 | baykit
# Processing Record 43 of Set 8 | the valley
# Processing Record 44 of Set 8 | jhanjharpur
# Processing Record 45 of Set 8 | narrabri
# Processing Record 46 of Set 8 | victoria
# Processing Record 47 of Set 8 | mpongwe
# Processing Record 48 of Set 8 | barawe
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 8 | sangmelima
# Processing Record 50 of Set 8 | qingyuan
# Processing Record 1 of Set 9 | bilibino
# Processing Record 2 of Set 9 | takaka
# Processing Record 3 of Set 9 | fortuna
# Processing Record 4 of Set 9 | axim
# Processing Record 5 of Set 9 | nome
# Processing Record 6 of Set 9 | komsomolskiy
# Processing Record 7 of Set 9 | tagusao
# Processing Record 8 of Set 9 | melita
# Processing Record 9 of Set 9 | bojnurd
# Processing Record 10 of Set 9 | ancud
# Processing Record 11 of Set 9 | aklavik
# Processing Record 12 of Set 9 | makarska
# Processing Record 13 of Set 9 | mana
# Processing Record 14 of Set 9 | mouzakion
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 9 | tumannyy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 9 | maneadero
# Processing Record 17 of Set 9 | sotik
# Processing Record 18 of Set 9 | kasongo-lunda
# Processing Record 19 of Set 9 | toamasina
# Processing Record 20 of Set 9 | shetpe
# Processing Record 21 of Set 9 | alta floresta
# Processing Record 22 of Set 9 | kazalinsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 9 | pousat
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 9 | indiana
# Processing Record 25 of Set 9 | honningsvag
# Processing Record 26 of Set 9 | palafrugell
# Processing Record 27 of Set 9 | bauta
# Processing Record 28 of Set 9 | aksarka
# Processing Record 29 of Set 9 | kilimatinde
# Processing Record 30 of Set 9 | wulanhaote
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 9 | norway
# Processing Record 32 of Set 9 | san policarpo
# Processing Record 33 of Set 9 | san carlos de bariloche
# Processing Record 34 of Set 9 | prince rupert
# Processing Record 35 of Set 9 | longlac
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 9 | samarinda
# Processing Record 37 of Set 9 | kushiro
# Processing Record 38 of Set 9 | porosozero
# Processing Record 39 of Set 9 | manaure
# Processing Record 40 of Set 9 | cabo rojo
# Processing Record 41 of Set 9 | ellensburg
# Processing Record 42 of Set 9 | krasnyy chikoy
# Processing Record 43 of Set 9 | turan
# Processing Record 44 of Set 9 | mitsamiouli
# Processing Record 45 of Set 9 | christchurch
# Processing Record 46 of Set 9 | tutoia
# Processing Record 47 of Set 9 | tarko-sale
# Processing Record 48 of Set 9 | maruko
# Processing Record 49 of Set 9 | praia
# Processing Record 50 of Set 9 | verkhnevilyuysk
# Processing Record 1 of Set 10 | kununurra
# Processing Record 2 of Set 10 | paraopeba
# Processing Record 3 of Set 10 | nyimba
# Processing Record 4 of Set 10 | corrales
# Processing Record 5 of Set 10 | krasnyy yar
# Processing Record 6 of Set 10 | reus
# Processing Record 7 of Set 10 | adre
# Processing Record 8 of Set 10 | bubaque
# Processing Record 9 of Set 10 | pringsewu
# Processing Record 10 of Set 10 | changli
# Processing Record 11 of Set 10 | koungou
# Processing Record 12 of Set 10 | sistranda
# Processing Record 13 of Set 10 | quepos
# Processing Record 14 of Set 10 | sfantu gheorghe
# Processing Record 15 of Set 10 | maracas
# Processing Record 16 of Set 10 | saleaula
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 10 | yeppoon
# Processing Record 18 of Set 10 | batemans bay
# Processing Record 19 of Set 10 | kursavka
# Processing Record 20 of Set 10 | platon sanchez
# Processing Record 21 of Set 10 | tabou
# Processing Record 22 of Set 10 | sarahan
# Processing Record 23 of Set 10 | coquimbo
# Processing Record 24 of Set 10 | novyy urgal
# Processing Record 25 of Set 10 | lushunkou
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 10 | ilulissat
# Processing Record 27 of Set 10 | colac
# Processing Record 28 of Set 10 | ardakan
# Processing Record 29 of Set 10 | atar
# Processing Record 30 of Set 10 | gualaca
# Processing Record 31 of Set 10 | vorotynsk
# Processing Record 32 of Set 10 | tuim
# Processing Record 33 of Set 10 | yerbogachen
# Processing Record 34 of Set 10 | itoman
# Processing Record 35 of Set 10 | potsdam
# Processing Record 36 of Set 10 | aripuana
# Processing Record 37 of Set 10 | agva
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 10 | yeehaw junction
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 10 | faya
# Processing Record 40 of Set 10 | nuuk
# Processing Record 41 of Set 10 | los llanos de aridane
# Processing Record 42 of Set 10 | ghatal
# Processing Record 43 of Set 10 | grand-santi
# Processing Record 44 of Set 10 | sept-iles
# Processing Record 45 of Set 10 | marcona
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 10 | bombay
# Processing Record 47 of Set 10 | priladozhskiy
# Processing Record 48 of Set 10 | zhanatas
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 10 | bezhetsk
# Processing Record 50 of Set 10 | siniscola
# Processing Record 1 of Set 11 | shizilu
# Processing Record 2 of Set 11 | sambava
# Processing Record 3 of Set 11 | fevralsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 11 | inuvik
# Processing Record 5 of Set 11 | tibati
# Processing Record 6 of Set 11 | kyaikkami
# Processing Record 7 of Set 11 | saint anthony
# Processing Record 8 of Set 11 | novodugino
# Processing Record 9 of Set 11 | batticaloa
# Processing Record 10 of Set 11 | havre-saint-pierre
# Processing Record 11 of Set 11 | kostrzyn
# Processing Record 12 of Set 11 | svetlyy
# Processing Record 13 of Set 11 | coihueco
# Processing Record 14 of Set 11 | pangody
# Processing Record 15 of Set 11 | kauhajoki
# Processing Record 16 of Set 11 | zhigansk
# Processing Record 17 of Set 11 | elista
# Processing Record 18 of Set 11 | eureka
# Processing Record 19 of Set 11 | privodino
# Processing Record 20 of Set 11 | vostok
# Processing Record 21 of Set 11 | wilmington
# Processing Record 22 of Set 11 | hami
# Processing Record 23 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 11 | vikulovo
# Processing Record 25 of Set 11 | boyolangu
# Processing Record 26 of Set 11 | broome
# Processing Record 27 of Set 11 | palabuhanratu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 11 | livramento
# Processing Record 29 of Set 11 | sandwick
# Processing Record 30 of Set 11 | bonfim
# Processing Record 31 of Set 11 | barstow
# Processing Record 32 of Set 11 | harper
# Processing Record 33 of Set 11 | chegdomyn
# Processing Record 34 of Set 11 | balakhta
# Processing Record 35 of Set 11 | port augusta
# Processing Record 36 of Set 11 | tromso
# Processing Record 37 of Set 11 | bagado
# Processing Record 38 of Set 11 | haapiti
# Processing Record 39 of Set 11 | trairi
# Processing Record 40 of Set 11 | scottsburgh
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 11 | poum
# Processing Record 42 of Set 11 | yantarnyy
# Processing Record 43 of Set 11 | kotka
# Processing Record 44 of Set 11 | de-kastri
# Processing Record 45 of Set 11 | husavik
# Processing Record 46 of Set 11 | kinkala
# Processing Record 47 of Set 11 | koslan
# Processing Record 48 of Set 11 | lerwick
# Processing Record 49 of Set 11 | bajo baudo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 11 | martapura
# Processing Record 1 of Set 12 | lavrentiya
# Processing Record 2 of Set 12 | antalaha
# Processing Record 3 of Set 12 | rawson
# Processing Record 4 of Set 12 | beyneu
# Processing Record 5 of Set 12 | porto novo
# Processing Record 6 of Set 12 | san cristobal
# Processing Record 7 of Set 12 | marshall
# Processing Record 8 of Set 12 | acarau
# Processing Record 9 of Set 12 | sioux lookout
# Processing Record 10 of Set 12 | vanimo
# Processing Record 11 of Set 12 | wufeng
# Processing Record 12 of Set 12 | ballina
# Processing Record 13 of Set 12 | utiroa
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 12 | osoyoos
# Processing Record 15 of Set 12 | kralendijk
# Processing Record 16 of Set 12 | samusu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 12 | caravelas
# Processing Record 18 of Set 12 | winnemucca
# Processing Record 19 of Set 12 | monrovia
# Processing Record 20 of Set 12 | puerto ayacucho
# Processing Record 21 of Set 12 | cockburn town
# Processing Record 22 of Set 12 | nicoya
# Processing Record 23 of Set 12 | buraydah
# Processing Record 24 of Set 12 | beaufort
# Processing Record 25 of Set 12 | shache
# Processing Record 26 of Set 12 | newport
# Processing Record 27 of Set 12 | lieksa
# Processing Record 28 of Set 12 | balatonszabadi
# Processing Record 29 of Set 12 | vestmannaeyjar
# Processing Record 30 of Set 12 | gbarnga
# Processing Record 31 of Set 12 | knysna
# Processing Record 32 of Set 12 | sechura
# Processing Record 33 of Set 12 | samarkand
# Processing Record 34 of Set 12 | arlit
# Processing Record 35 of Set 12 | alappuzha
# Processing Record 36 of Set 12 | domoni
# Processing Record 37 of Set 12 | sassandra
# Processing Record 38 of Set 12 | jalu
# Processing Record 39 of Set 12 | tucuman
# Processing Record 40 of Set 12 | roma
# Processing Record 41 of Set 12 | doha
# Processing Record 42 of Set 12 | grand river south east
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 12 | badnawar
# Processing Record 44 of Set 12 | siutu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 12 | phumi samraong
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 12 | cusuna
# Processing Record 47 of Set 12 | mungwi
# Processing Record 48 of Set 12 | sarkand
# Processing Record 49 of Set 12 | ornskoldsvik
# Processing Record 50 of Set 12 | crixas
# Processing Record 1 of Set 13 | moose factory
# Processing Record 2 of Set 13 | le vauclin
# Processing Record 3 of Set 13 | riyadh
# Processing Record 4 of Set 13 | le port
# Processing Record 5 of Set 13 | morondava
# Processing Record 6 of Set 13 | rocha
# Processing Record 7 of Set 13 | marawi
# Processing Record 8 of Set 13 | ostrovnoy
# Processing Record 9 of Set 13 | tazovskiy
# Processing Record 10 of Set 13 | skiros
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 13 | abalak
# Processing Record 12 of Set 13 | skelleftea
# Processing Record 13 of Set 13 | katobu
# Processing Record 14 of Set 13 | isiro
# Processing Record 15 of Set 13 | rungata
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 13 | mamontovo
# Processing Record 17 of Set 13 | pallasovka
# Processing Record 18 of Set 13 | payakumbuh
# Processing Record 19 of Set 13 | dubai
# Processing Record 20 of Set 13 | bama
# Processing Record 21 of Set 13 | taunggyi
# Processing Record 22 of Set 13 | akhmeta
# Processing Record 23 of Set 13 | svetlogorsk
# Processing Record 24 of Set 13 | sorvag
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 13 | tukrah
# Processing Record 26 of Set 13 | kudahuvadhoo
# Processing Record 27 of Set 13 | hue
# Processing Record 28 of Set 13 | kapit
# Processing Record 29 of Set 13 | cheuskiny
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 13 | bambanglipuro
# Processing Record 31 of Set 13 | sisimiut
# Processing Record 32 of Set 13 | maceio
# Processing Record 33 of Set 13 | belmonte
# Processing Record 34 of Set 13 | terrace
# Processing Record 35 of Set 13 | nelson bay
# Processing Record 36 of Set 13 | campos novos
# Processing Record 37 of Set 13 | poso
# Processing Record 38 of Set 13 | zaysan
# Processing Record 39 of Set 13 | aykhal
# Processing Record 40 of Set 13 | tabas
# Processing Record 41 of Set 13 | kulhudhuffushi
# Processing Record 42 of Set 13 | akyab
# Processing Record 43 of Set 13 | great yarmouth
# Processing Record 44 of Set 13 | okakarara
# Processing Record 45 of Set 13 | bandarbeyla
# Processing Record 46 of Set 13 | liniere
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 13 | turukhansk
# Processing Record 48 of Set 13 | porto uniao
# Processing Record 49 of Set 13 | mansa
# Processing Record 50 of Set 13 | grand gaube
# Processing Record 1 of Set 14 | xadani
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 14 | grindavik
# Processing Record 3 of Set 14 | cuamba
# Processing Record 4 of Set 14 | cam ranh
# Processing Record 5 of Set 14 | qurayyat
# Processing Record 6 of Set 14 | beckley
# Processing Record 7 of Set 14 | aksay
# Processing Record 8 of Set 14 | sindor
# Processing Record 9 of Set 14 | puerto madryn
# Processing Record 10 of Set 14 | qujing
# Processing Record 11 of Set 14 | haibowan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 14 | cairns
# Processing Record 13 of Set 14 | houma
# Processing Record 14 of Set 14 | labuhan
# Processing Record 15 of Set 14 | massagno
# Processing Record 16 of Set 14 | villeneuve-les-avignon
# Processing Record 17 of Set 14 | batagay
# Processing Record 18 of Set 14 | afmadu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 14 | berlevag
# Processing Record 20 of Set 14 | shchelyayur
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 14 | montepuez
# Processing Record 22 of Set 14 | kilifi
# Processing Record 23 of Set 14 | ravar
# Processing Record 24 of Set 14 | mopti
# Processing Record 25 of Set 14 | klaeng
# Processing Record 26 of Set 14 | laguna
# Processing Record 27 of Set 14 | ponta delgada
# Processing Record 28 of Set 14 | shimoda
# Processing Record 29 of Set 14 | rehoboth
# Processing Record 30 of Set 14 | igarka
# Processing Record 31 of Set 14 | lyubech
# Processing Record 32 of Set 14 | madaoua
# Processing Record 33 of Set 14 | elko
# Processing Record 34 of Set 14 | sabla
# Processing Record 35 of Set 14 | okhotsk
# Processing Record 36 of Set 14 | wukari
# Processing Record 37 of Set 14 | mackay
# Processing Record 38 of Set 14 | pisco
# Processing Record 39 of Set 14 | mutata
# Processing Record 40 of Set 14 | babanka
# Processing Record 41 of Set 14 | whitecourt
# Processing Record 42 of Set 14 | kandrian
# Processing Record 43 of Set 14 | bad doberan
# Processing Record 44 of Set 14 | vila praia de ancora
# Processing Record 45 of Set 14 | abha
# Processing Record 46 of Set 14 | praya
# Processing Record 47 of Set 14 | nyurba
# Processing Record 48 of Set 14 | luan
# Processing Record 49 of Set 14 | deputatskiy
# Processing Record 50 of Set 14 | bay city
# Processing Record 1 of Set 15 | kota kinabalu
# Processing Record 2 of Set 15 | honiara
# Processing Record 3 of Set 15 | mount isa
# Processing Record 4 of Set 15 | rundu
# Processing Record 5 of Set 15 | songea
# Processing Record 6 of Set 15 | chicama
# Processing Record 7 of Set 15 | gonnoi
# Processing Record 8 of Set 15 | westport
# Processing Record 9 of Set 15 | nayagarh
# Processing Record 10 of Set 15 | sol-iletsk
# Processing Record 11 of Set 15 | beira
# Processing Record 12 of Set 15 | marsa matruh
# Processing Record 13 of Set 15 | verkhnetulomskiy
# Processing Record 14 of Set 15 | haines junction
# Processing Record 15 of Set 15 | alibag
# Processing Record 16 of Set 15 | kilcormac
# Processing Record 17 of Set 15 | baruun-urt
# Processing Record 18 of Set 15 | semporna
# Processing Record 19 of Set 15 | bahadurganj
# Processing Record 20 of Set 15 | whitehorse
# Processing Record 21 of Set 15 | umm lajj
# Processing Record 22 of Set 15 | aksum
# Processing Record 23 of Set 15 | vila velha
# Processing Record 24 of Set 15 | kushima
# Processing Record 25 of Set 15 | jutai
# Processing Record 26 of Set 15 | kropotkin
# Processing Record 27 of Set 15 | acheng
# Processing Record 28 of Set 15 | auki
# Processing Record 29 of Set 15 | santa cruz de la palma
# Processing Record 30 of Set 15 | xaxim
# Processing Record 31 of Set 15 | chumikan
# Processing Record 32 of Set 15 | shpykiv
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 15 | charlottesville
# Processing Record 34 of Set 15 | maldonado
# Processing Record 35 of Set 15 | kenora
# Processing Record 36 of Set 15 | kisangani

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Upernavik  72.7868  -56.1549     26.98        68          68
# 1            Natal  -5.7950  -35.2094     86.65        66          40
# 2  Bambous Virieux -20.3428   57.7575     77.25        78          40
# 3        Quelimane -17.8786   36.8883     73.80        93           9
# 4            Airai  -8.9266  125.4092     59.04        88          71
# 5   Ribeira Grande  38.5167  -28.7000     64.80        77          20
# 6      New Norfolk -42.7826  147.0587     50.90        82         100
# 7           Marsta  59.6216   17.8548     48.16        42           0
# 8           Albany  42.6001  -73.9662     53.26        79         100
# 9         Souillac -20.5167   57.5167     77.38        78          40
#
#    Wind Speed Country       Description                 Date
# 0        5.59      GL     broken clouds  2022-04-26 16:05:43
# 1       14.97      BR  scattered clouds  2022-04-26 16:05:44
# 2       11.50      MU        light rain  2022-04-26 16:05:45
# 3        5.88      MZ        light rain  2022-04-26 16:05:46
# 4        0.74      TL     broken clouds  2022-04-26 16:05:46
# 5       14.97      PT        few clouds  2022-04-26 15:59:29
# 6        2.15      AU   overcast clouds  2022-04-26 16:05:47
# 7       10.36      SE         clear sky  2022-04-26 16:05:47
# 8        1.16      US   overcast clouds  2022-04-26 16:04:44
# 9       11.50      MU        light rain  2022-04-26 16:05:05

# %%
city_data_df = city_data_df.drop(['Date'], axis = 1)
city_data_df = city_data_df.rename(columns={"Description":"Current Description"})
city_data_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Upernavik  72.7868  -56.1549     26.98        68          68
# 1              Natal  -5.7950  -35.2094     86.65        66          40
# 2    Bambous Virieux -20.3428   57.7575     77.25        78          40
# 3          Quelimane -17.8786   36.8883     73.80        93           9
# 4              Airai  -8.9266  125.4092     59.04        88          71
# ..               ...      ...       ...       ...       ...         ...
# 662         Chumikan  54.7183  135.3150     25.07        91         100
# 663  Charlottesville  38.0293  -78.4767     76.08        69          75
# 664        Maldonado -34.6667  -54.9167     75.22        72          78
# 665           Kenora  49.8167  -94.4337     25.77        68          75
# 666        Kisangani   0.5167   25.2000     78.39        76          99
#
#      Wind Speed Country Current Description
# 0          5.59      GL       broken clouds
# 1         14.97      BR    scattered clouds
# 2         11.50      MU          light rain
# 3          5.88      MZ          light rain
# 4          0.74      TL       broken clouds
# ..          ...     ...                 ...
# 662        1.48      RU     overcast clouds
# 663        4.61      US       broken clouds
# 664       12.44      UY       broken clouds
# 665        4.61      CA       broken clouds
# 666        3.29      CD     overcast clouds
#
# [667 rows x 9 columns]

# %%
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Upernavik      GL  72.7868  -56.1549     26.98        68          68
# 1            Natal      BR  -5.7950  -35.2094     86.65        66          40
# 2  Bambous Virieux      MU -20.3428   57.7575     77.25        78          40
# 3        Quelimane      MZ -17.8786   36.8883     73.80        93           9
# 4            Airai      TL  -8.9266  125.4092     59.04        88          71
# 5   Ribeira Grande      PT  38.5167  -28.7000     64.80        77          20
# 6      New Norfolk      AU -42.7826  147.0587     50.90        82         100
# 7           Marsta      SE  59.6216   17.8548     48.16        42           0
# 8           Albany      US  42.6001  -73.9662     53.26        79         100
# 9         Souillac      MU -20.5167   57.5167     77.38        78          40
#
#    Wind Speed Current Description
# 0        5.59       broken clouds
# 1       14.97    scattered clouds
# 2       11.50          light rain
# 3        5.88          light rain
# 4        0.74       broken clouds
# 5       14.97          few clouds
# 6        2.15     overcast clouds
# 7       10.36           clear sky
# 8        1.16     overcast clouds
# 9       11.50          light rain

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
